# %%
pip install rdflib
# Out:
# ...
#      |████████████████████████████████| 482 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 41 kB 442 kB/s
# ...

# %%
#imports
import numpy as np
import pandas as pd
import rdflib

# %%
# Get data from csv
gares = pd.read_csv('gares.csv', encoding='latin-1')
biblio = pd.read_csv('biblio.csv', sep=';', encoding='latin-1', on_bad_lines='skip')
gares = gares[['Nom_Gare', 'INSEE_DEP', 'Latitude', 'Longitude']]
biblio = biblio[['Libelle1', 'DEPT', 'coordonnees_finales']]
coordonnees = [str(biblio["coordonnees_finales"].iloc[i]).split(',') for i in range(biblio["coordonnees_finales"].size)]
latitude = []
longitude = []
for coord in coordonnees:
  if coord[0] == 'nan':
    latitude.append(None)
    longitude.append(None)
  else:
    latitude.append(float(coord[0]))
    longitude.append(float(coord[1]))
biblio.drop(columns = ["coordonnees_finales"])
biblio["Latitude"] = latitude
biblio["Longitude"] = longitude
biblio.head()
# Out:
#                                  Libelle1 DEPT coordonnees_finales   Latitude  \
# 0                BibliothÃ¨que Municipale   60  49.284913,2.988443  49.284913
# 1       Activites Et Loisirs De Boursonne   60  49.202875,3.046898  49.202875
# 2         BibliothÃ¨que De Boury En Vexin   60  49.240743,1.736919  49.240743
# 3      BibliothÃ¨que Municipale De Bulles   60   49.45859,2.325491  49.458590
# 4  BIBLIOTHEQUE DE CAMBRONNE LES CLERMONT   60  49.329964,2.398457  49.329964
#
#    Longitude
# 0   2.988443
# 1   3.046898
# 2   1.736919
# 3   2.325491
# 4   2.398457

# %%
from rdflib import Graph, Literal, RDF, URIRef
# rdflib knows about quite a few popular namespaces, like W3C ontologies, schema.org etc.
from rdflib.namespace import FOAF , XSD

# Create a Graph
g = Graph()
g.parse("ontology.owl")
print(g.serialize())
# Out:
# @prefix : <http://www.semanticweb.org/qnava/ontologies/2022/2/untitled-ontology-15#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://www.semanticweb.org/qnava/ontologies/2022/2/untitled-ontology-15> a owl:Ontology .
#
# :Aix-en-Provence_TGV a :TrainStation,
#         owl:NamedIndividual ;
#     :departement 1 ;
#     :latitude 46.097 ;
#     :longitude 4.847 ;
#     :name "Aix-en-Provence_TGV" .
#
# :Library a owl:Class ;
#     rdfs:subClassOf :Place ;
#     owl:disjointWith :TrainStation .
#
# :Paris-Bordeaux a :TrainTrip,
#         owl:NamedIndividual ;
#     :arrivalsStation :Bordeaux-Saint-Jean ;
#     :date "23/03/2022" ;
#     :departuresStation :Paris-Montparnasse .
#
# :Peter a :Person,
#         owl:NamedIndividual ;
#     :birthDate "02/10/1995" ;
#     :familyName "Dupont" ;
#     :givenName "Peter" .
#
# :birthDate a owl:DatatypeProperty ;
# ...
